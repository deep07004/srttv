# %%
from bokeh.plotting import figure, show
from bokeh.transform import factor_cmap, factor_hatch
from bokeh.io import output_notebook
import numpy as np
from bokeh.models import LinearColorMapper
output_notebook()
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
latancy = [' <60', ' <60', ' <60', ' <300', ' <300', ' <300', ' <600', ' <600', ' <600',' <600']
data = {'lat':np.random.rand(10),'lon':np.random.rand(10),'latancy':latancy}

# %%
cmap = ['#FF0000','#3BB143','#FFBF00']
p = figure(title='test test test')
p.triangle(x='lat',y='lon',size=12, source=data, legend_group="latancy", color=factor_cmap('latancy', cmap,[' <60', ' <300', ' <600']))
p.legend[0].items[0], p.legend[0].items[1] = p.legend[0].items[1], p.legend[0].items[0]
show(p)
# Out:
#   <div class="bk-root" id="56bea18c-a575-4624-9b7e-4a2c637d475d" data-root-id="1003"></div>

# %%
p.legend[0].items[0], p.legend[0].items[1] = p.legend[0].items[1], p.legend[0].items[0]

# %%
p.legend[0].items
# Out:
# [LegendItem(id='5220', ...),
#  LegendItem(id='5219', ...),
#  LegendItem(id='5221', ...)]
